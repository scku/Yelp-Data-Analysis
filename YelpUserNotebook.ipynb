# %% [markdown]
# # Build a Social Network Graph

# %%
# %load_ext rmagic
import rpy2 as Rpy

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%R
# data_user <- read.csv("yelp_academic_dataset_user.csv", stringsAsFactors=FALSE)
# cat("Dimension of user dataset:\n"); print(dim(data_user))
# cat("Summary of user dataset:\n"); print(names(data_user))
# Out:
# Dimension of user dataset:
# [1] 70817    23
# Summary of user dataset:
#  [1] "average_stars"       "compliments_cool"    "compliments_cute"
#  [4] "compliments_funny"   "compliments_hot"     "compliments_list"
#  [7] "compliments_more"    "compliments_note"    "compliments_photos"
# [10] "compliments_plain"   "compliments_profile" "compliments_writer"
# [13] "elite"               "fans"                "friends"
# [16] "name"                "review_count"        "type"
# [19] "user_id"             "votes_cool"          "votes_funny"
# [22] "votes_useful"        "yelping_since"

# %%
# %%R
# indices <- data_user$friends!="[,]" # only sample users with friends
# data_user_f <- data_user[indices,]
# cat("Dimension of user dataset  w/ friends:\n"); print(dim(data_user_f))
# Out:
# Dimension of user dataset  w/ friends:
# [1] 30255    23

# %%
# %%R
# #R Function Definitions
# preprocess_friendlist <- function(dirty_friend_list ){
#     friend_list<-dirty_friend_list
#     friend_list<-gsub(',', '', friend_list, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
#     friend_list<-gsub("u'", "", friend_list, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
#     friend_list<-gsub("'", ",", friend_list, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
#     friend_list<-gsub(",]", "", friend_list, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
#     friend_list<-gsub("\\[", "", friend_list, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
#     return(friend_list)
# }

# %%
# %%R
# # First Approach - Build a graph by randomly subsampling n yelp users to try to get some sense of the
# #underlying social media structure
# random_data_sample <- data_user_f[sample(nrow(data_user_f), 1000, replace = FALSE, prob = NULL),] #sampling a small # to run faster
# cat("Dimension of user dataset sample w/ friends:\n"); print(dim(random_data_sample))
# cat("Summary of user dataset sample w/ friends:\n"); print(names(random_data_sample))
#
# ##PREPROCESSING - this is defined as a function above so we can probably invoke it here
# keeps <- c("user_id","friends") # we are only interested in friends / connectivity
# random_friend_list <- random_data_sample[keeps]
# random_friend_list<- preprocess_friendlist(random_data_sample$friends)
#
# #prints the first 5 elements of dataframe
# cat("Length of friend list string for randomly subsampled users:\n"); print(nchar(random_friend_list))
# Out:
# Dimension of user dataset sample w/ friends:
# [1] 1000   23
# Summary of user dataset sample w/ friends:
#  [1] "average_stars"       "compliments_cool"    "compliments_cute"
#  [4] "compliments_funny"   "compliments_hot"     "compliments_list"
#  [7] "compliments_more"    "compliments_note"    "compliments_photos"
# [10] "compliments_plain"   "compliments_profile" "compliments_writer"
# [13] "elite"               "fans"                "friends"
# [16] "name"                "review_count"        "type"
# [19] "user_id"             "votes_cool"          "votes_funny"
# [22] "votes_useful"        "yelping_since"
# Length of friend list string for randomly subsampled users:
#    [1]   502    46  3214    22    22    22    22    46   214   142   310    94
#   [13]   118   406    94   334   262    70   574   142    22   238   238   142
#   [25]    70    94    22    70    46    46   190    22    22   430   166   358
#   [37]   190    46    22    94    46    46   190   190   910    22    46    22
#   [49]    22    22    22    22    46    22   238    70    94    22    22   118
#   [61]    22    70   142    22    70    46    46    46    70    22    22   142
#   [73]   166    22    46   574    22   190    22  3670    94    22    46    22
#   [85]    22    70   526   118    22    70   190   238    22    70    46    22
#   [97]    22    22   334   622    46   886    22    22   118    22    22    22
#  [109]    46    22  2974   478    94   190    22   430    70  1870    46    22
#  [121]    46   238    22    22    70    22    22    46    70    22    94   166
#  [133]    70    70   694   382   142    22    22    22    22   118    22    46
#  [145]   814    22   142   286    22    22    22   166    94    46    46    94
#  [157]    22   118   190    22    22    22   190  1270    22    46    46    46
#  [169]   118   910   262    94    22    46    22   310    70    22    22    70
#  [181]    22   526    46   142    22    22    22    46    46   142    22    22
#  [193]    22   286   334   286    22   214    46  1510   382    22   478    22
#  [205]   142    46    94    22    70   382   118    94   166    46    46   118
#  [217]    22    70   238    70    46   310    22   310   910   190    22    46
#  [229]    46   118    94    70   166   742   382   166    22    94   310    46
#  [241]    22    22   430    46    22    22   142   238    94    46   214    46
#  [253]   118    46   766    22   838    94   166  1366   118    22    46   742
#  [265]    70   814   670    46    46   526    70    46    70    70    70    94
#  [277]   406    70   166    22   574   142    46    46    46    46   142    22
#  [289]    22    70    70   646    22  1486    46   118    70    94    22    70
#  [301]   118    46    70    22    22    46    46   358   166   214   262   910
#  [313]    22    22    22    22   934   478    22   742    46   118   118   118
#  [325]    22    22    46    94    46    22    46    46  1102    46   118    22
#  [337]    70    46    22   358   286    46    46    46    46    46    22   910
#  [349]   190    22   550    70   190    70   286    22    22   166    70  2590
#  [361]    46   382    22    22    46    22  1174    22    70    22    94    70
#  [373]    70   190    46    22   574   142    22   118    70   550    22   598
#  [385]    46  2614   214    22    46    70   238    46    46   190    70    94
#  [397]   142   358   214    22    70    46    46    70  1774   334    46   166
#  [409]    46    22   118   166   430    22    22  2854    70    94   838    70
#  [421]   118   190    46    22    94   214    46   430    22   718    94    46
#  [433]   190   190    22  1630    22   742  1510   118   118   214    70    22
#  [445]   190    22    70    22   358    70    22   478    94   190    46  2230
#  [457]    22    46    22    22    22    70   406    94  3118    46   694    46
#  [469]   142   646    46   190    22    22    46   406   142  1294   214   118
#  [481]   142    22   166    94    22    22    94    22    46    22    22   118
#  [493]    22    46  4798    46   166    46   190 17014    22   478   190    46
#  [505]  1462   142    94   502   118    70   262    22    22   694    22  1630
#  [517]   118   286    46   118  1510    22    94    22    46   214    46    22
#  [529]   286   358   142    70    70    22    22   142    22    22    70   790
#  [541]   166    22    46    22    22   670   262    46    94   238    70   142
#  [553]  1582   862   358    94    22    22    70    46    22   430   166    22
#  [565]    46    22    94    22    22   118    22    22   142   766    22   142
#  [577]   118    22    22    46    22    70  1174    94    94   166   358    22
#  [589]   502    22    22   142    22   142   118    22  1150    22    46    22
#  [601]    94    70    94    22    94   190   142    46    46  3334    70   118
#  [613]   142    22    94    94    22   118   142    46   334    22   262    94
#  [625]    70   118    22   118    22   478    22    22    22   142    22   238
#  [637]    46    94    46    46    22    46   214   406    22   118    22    46
#  [649]    22    22    22   334   214   166  1366   166    22    46    46    70
#  [661]    22   142  1006    46    22   406   118    46    22    22   214   358
#  [673]    22   190    22    46    46   358    70   118    70    46    22    22
#  [685]  2014    46    70    22    22    46    22    70    22  1534    22    46
#  [697]    22    94    46    46    22    22    46    70   142    22    70    46
#  [709]    46    22   646    22    46    22   310   334  1486    22    70    94
#  [721]    22   502   142    22    22   262    22    22    22   430    22    70
#  [733]    22    46    22   190   214   190    22    94    46    70    22   286
#  [745]    94  1102    46    22    94    70   958   214    46   406   502    22
#  [757]    94   166    46   334    70    46   550    22   190    22    46    46
#  [769]    22    22    22   478   814    22    46    22    22  1270    46   670
#  [781]   166  1222    70   694   142   382    22    70    22    46  1270    22
#  [793]    22  1246   118    70    22    70    70   118    22    22   166   118
#  [805]    94   118   166    46    94    70    22    46   334   622    70    46
#  [817]   142    22   118   406    22    22    22   382    94   166   190   718
#  [829]    70    46   214    22    94    22   214    46    46    22   118   214
#  [841]   214    94    22    46   118   430    22    94   334    22    46  1054
#  [853]    22   190   310   118    46   286    70   766    22    70    46    22
#  [865]    22    46   334    46    46    94    22    22    22    70   118    22
#  [877]  1150    22    22    22   166    22    70    22    94    70    22    46
#  [889]    46    94    70   214   118   142    22   118    22    22    94    22
#  [901]   478    70   142   574   286    22    22   982   262    22    46    22
#  [913]   358   166    22   550   118    46   838    22    22    70   142   142
#  [925]    46   958    22  1054    22    22    94   382   238    22    46   142
#  [937]   118   142   718 10558    22   742    46    70    22    22   238    46
#  [949]    22    22   142   310   334  6526    22   118    46   142    22  5686
#  [961]   694    22    22   118    94    46    22  1150   262   238   382   190
#  [973]    22    46    94  1270  1318   622    22    46    94    22    46   262
#  [985]    22    22    94    22    22    94    70   262    94   310   406    22
#  [997]    94   910    22    22

# %%
# %%R
# # second Approach - Build a graph of the most popular yelp users (users with the most friends)
# ndx = order(nchar(data_user_f$friends),decreasing=TRUE)
# data_user_f_sorted = data_user_f[ndx,]
# keeps <- c("user_id","friends") # we are only interested in friends / connectivity
# data_user_f_sorted <- data_user_f_sorted[keeps]
# data_sorted_10 = data_user_f_sorted[1:10,]
# data_sorted_20 = data_user_f_sorted[1:20,]
# data_sorted_50 = data_user_f_sorted[1:50,]
# data_sorted_100 = data_user_f_sorted[1:100,]
# data_sorted_500 = data_user_f_sorted[1:500,]
# data_sorted_1000 = data_user_f_sorted[1:1000,]
# #cat("Dimension of user dataset sample w/ friends:\n"); print(dim(data_sample))
# #cat("Summary of user dataset sample w/ friends:\n"); print(names(data_sample))
#
#
# #print(str(data_sorted_50))
# ##PREPROCESSING
# friend_list_top10 <- preprocess_friendlist(data_sorted_10$friends)
# friend_list_top20 <- preprocess_friendlist(data_sorted_20$friends)
# friend_list_top50 <- preprocess_friendlist(data_sorted_50$friends)
# friend_list_top100 <- preprocess_friendlist(data_sorted_100$friends)
# friend_list_top500 <- preprocess_friendlist(data_sorted_500$friends)
# friend_list_top1000 <- preprocess_friendlist(data_sorted_1000$friends)

# %%
import networkx as nx
import matplotlib.pyplot as plt
num_of_friends = {}
def create_adj_list(friends_of_users,user_sample):
    adj_list = [] 
    for friend_list in friends_of_users: # create adj_list out of string
        cur_list = []
        friends = friend_list.split(', ')
        for friend in friends:
            if friend in user_sample:
                cur_list.append(friend)
                #adj_list.append(friend.split(', ')) # originally friend is a long string so we have to split on ", " to parse
        adj_list.append(cur_list)
    return(adj_list)


def create_graph(user_sample,adj_list):
    G=nx.Graph()
    num_nodes = len(user_sample)
    print "There are " + str(num_nodes) + " original subsampled nodes."
    for node in user_sample: # add all nodes to graph
        G.add_node(node)
    for i in range(num_nodes): #iterate over every node we subsampled
        num_of_friends[user_sample[i]] = len(adj_list[i])
        for friend in adj_list[i]: #iterate over adjacency list in node
            if friend !="":
                G.add_edge(user_sample[i],friend) # add all edges to graph
    return(G)

def plot_graph(G):
  #  print("Nodes of graph: "); print(G.nodes())
  #  print("Number of friends: "); print(num_of_friends)
  #  print(max(num_of_friends.itervalues()))
    fig = plt.figure(figsize=(15, 15))
    plt.title('Yelp Connectivity Graph')
    p = nx.degree_centrality(G)
    min_value = max(p.itervalues())
    #print min_value
    def f(dict):
        for entry in dict.items():
            dict[entry[0]] = entry[1] / min_value
        return dict
    p = f(p)
   # print p.values()
    values = [num_of_friends.get(node) for node in G.nodes()]
    values = [0 if x is None else x for x in values]
    #print values
    nx.draw(G, node_size=60, node_color=values, cmap=plt.get_cmap('jet'),
            with_labels=False, alpha=0.5, pos=nx.spring_layout(G))

# %%
import numpy
import networkx as nx
#create list of nodes an adjaceny list for each dataset, create and plot the graph
# %R -o random_friend_list
# %R -o random_data_sample

# %R -o friend_list_top10
# %R -o data_sorted_10

# %R -o friend_list_top20
# %R -o data_sorted_20

# %R -o friend_list_top50
# %R -o data_sorted_50

# %R -o friend_list_top100
# %R -o data_sorted_100

# %R -o friend_list_top500
# %R -o data_sorted_500

# %R -o friend_list_top1000
# %R -o data_sorted_1000

# %R -o friend_list_top1000
# %R -o data_sorted_1000

all_nodes_random = []
all_nodes_top10 = []
all_nodes_top20 = []
all_nodes_top50 = []
all_nodes_top100 = []
all_nodes_top500 = []
all_nodes_top1000 = []

for user in random_data_sample[0]: # all initial sampled users to our nodes set
    all_nodes_random.append(user)

for user in data_sorted_10[0]: # all initial sampled users to our nodes set
    all_nodes_top10.append(user)
for user in data_sorted_20[0]: # all initial sampled users to our nodes set
    all_nodes_top20.append(user)
for user in data_sorted_50[0]: # all initial sampled users to our nodes set
    all_nodes_top50.append(user)
for user in data_sorted_100[0]: # all initial sampled users to our nodes set
    all_nodes_top100.append(user)
for user in data_sorted_500[0]: # all initial sampled users to our nodes set
    all_nodes_top500.append(user)
for user in data_sorted_1000[0]: # all initial sampled users to our nodes set
    all_nodes_top1000.append(user)

adj_list_random = create_adj_list(random_friend_list,random_data_sample[0]) 
adj_list_top10 = create_adj_list(friend_list_top10,data_sorted_10[0]) 
adj_list_top20 = create_adj_list(friend_list_top20,data_sorted_20[0]) 
adj_list_top50 = create_adj_list(friend_list_top50,data_sorted_50[0]) 
adj_list_top100 = create_adj_list(friend_list_top100,data_sorted_100[0]) 
adj_list_top500 = create_adj_list(friend_list_top500,data_sorted_500[0]) 
adj_list_top1000 = create_adj_list(friend_list_top1000,data_sorted_1000[0]) 

print "Our randomly subsampled graph will have  " + str(len(all_nodes_random)) + " nodes."
print "Randomly subsampled adj list size: " + str(len(adj_list_random))

print "Our top 10 graph will have total " + str(len(all_nodes_top10)) + " nodes."
print "Top 10 adj list size: " + str(len(adj_list_top10))

print "Our top 50 graph will have total " + str(len(all_nodes_top50)) + " nodes."
print "Top 50 adj list size: " + str(len(adj_list_top50))

print "Our top 100 graph will have total " + str(len(all_nodes_top100)) + " nodes."
print "Top 100 adj list size: " + str(len(adj_list_top100))

print "Our top 500 graph will have total " + str(len(all_nodes_top500)) + " nodes."
print "Top 500 adj list size: " + str(len(adj_list_top500))

print "Our top 1000 graph will have total " + str(len(all_nodes_top1000)) + " nodes."
print "Top 1000 adj list size: " + str(len(adj_list_top1000))
#print(adj_list)
# Out:
# Our randomly subsampled graph will have  1000 nodes.
# Randomly subsampled adj list size: 1000
# Our top 10 graph will have total 10 nodes.
# Top 10 adj list size: 10
# Our top 50 graph will have total 50 nodes.
# Top 50 adj list size: 50
# Our top 100 graph will have total 100 nodes.
# Top 100 adj list size: 100
# Our top 500 graph will have total 500 nodes.
# Top 500 adj list size: 500
# Our top 1000 graph will have total 1000 nodes.
# Top 1000 adj list size: 1000

# %%
import networkx as nx
import matplotlib.pyplot as plt


G10 = create_graph(all_nodes_top10,adj_list_top10)
G20 = create_graph(all_nodes_top20,adj_list_top20)
G50 = create_graph(all_nodes_top50,adj_list_top50)
G100 = create_graph(all_nodes_top100,adj_list_top100)
G500 = create_graph(all_nodes_top500,adj_list_top500)
G1000 = create_graph(all_nodes_top1000,adj_list_top1000)
G_random = create_graph(all_nodes_random,adj_list_random)

#plot_graph(G_random) - was getting a divide by 0 error, seems to work with all the other datasets though
plot_graph(G10)
plot_graph(G20)
plot_graph(G50)
plot_graph(G100)
plot_graph(G500)
plot_graph(G1000)
# Out:
# There are 10 original subsampled nodes.
# There are 20 original subsampled nodes.
# There are 50 original subsampled nodes.
# There are 100 original subsampled nodes.
# There are 500 original subsampled nodes.
# There are 1000 original subsampled nodes.
# There are 1000 original subsampled nodes.

# %% [markdown]
# ##  STUFF UNDER THIS LINE IS OLD CODE / MAY NEED EDITING / MAY BE BROKEN / WORK IN PROGRESS

# %%
import numpy
import networkx as nx
##NOT SURE IF THIS CELL IS STILL RELAVENT
# %R -o friend_list

user_sample = friend_list[0] # original user subsample for constructing graph
friends_of_users = friend_list[1] #list of strings, where each string is list of adjacent nodes, we further parse below
all_nodes = [] #list of all nodes, including users and their friends
adj_list = [] #adjacency list per node, the results of the parsed friends_of_users list, a list of lists
num_of_friends = {}

for user in user_sample: # all initial sampled users to our nodes set
    all_nodes.append(user)
    

for friend_list in friends_of_users: # create adj_list out of string
    cur_list = []
    friends = friend_list.split(', ')
    for friend in friends:
        if friend in user_sample:
            cur_list.append(friend)
            #adj_list.append(friend.split(', ')) # originally friend is a long string so we have to split on ", " to parse
    adj_list.append(cur_list)

print "Our graph will have total " + str(len(all_nodes)) + " nodes."
print "Our adj list is  will have total " + str(len(adj_list)) + " long."
#print(adj_list)
# Out:
# Our graph will have total 100 nodes.
# Our adj list is  will have total 100 long.

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()

# adding just one node:
num_nodes = len(user_sample)
print "There are " + str(num_nodes) + " original subsampled nodes."

for node in all_nodes: # add all nodes to graph
    G.add_node(node)

for i in range(num_nodes): #iterate over every node we subsampled
    num_of_friends[user_sample[i]] = len(adj_list[i])
    for friend in adj_list[i]: #iterate over adjacency list in node
        if friend !="":
            G.add_edge(user_sample[i],friend) # add all edges to graph

#print("Nodes of graph: "); print(G.nodes())
#print("Edges of graph: "); print(G.edges())
print("Number of friends: "); print(num_of_friends)
print(max(num_of_friends.itervalues()))
# Out:
# There are 100 original subsampled nodes.
# Number of friends:
# {'BKo0QW3LGBzAZug4doJrgA': 32, 'WEXsw5ads44QmglVA-t1GQ': 43, '8p4at4zdzCpueAmSBaorZA': 57, 'N1Q6HiZvnZHjNU712Gymqw': 34, 'J2JfCaiaZku8HgfNceU8Rg': 22, 'y8ZCNq8HSGDSx7Vm-NYEOw': 33, '1BW2HC851fJKPfJeQxjkTA': 66, '34gJ_KlP3RM6jotNT6TcDQ': 45, 'AYGHNy8gPxl2Q-etTT3hZw': 42, 'uBp2Jmip2qXQ0iWHUDY9sQ': 39, 'lC0KGXmIhyjzghBUlVnkhQ': 38, 'usQTOj7LQ9v0Fl98gRa3Iw': 41, 'mFOZOsPQOacWIMVSyXbEbg': 35, 'uTc1puvwUpFYryEHo4DNaA': 32, 'nrOCJCQUgXwdUIwg8QHirw': 41, 'C6IOtaaYdLIT5fWd7ZYIuA': 61, 'oC0kwGvgaAeT3ZIxdxTcJA': 44, 'BRydUrmdK4pZsbUvZ8tBAw': 48, 'hFtlFksrcLaWHGPNa6SmeA': 58, 'lmiDCrmas8TxRsbIGZX9Pg': 57, 'sEWeeq41k4ohBz4jS_iGRw': 45, 'vwLmvuSyt2qervMRFennHw': 38, 'ZZ43etAB2n_T53YBYtf8Dw': 35, 'cRyNICH0mhjxagvSyVr60Q': 71, '8E0DGec8LNn6oDmPHmj-mg': 39, 'PWXJpyVyAKtVehw4suOimg': 40, '90a6z--_CUrl84aCzZyPsg': 63, 'n_lAaNGeWgspbbCJc0DqRg': 45, 'fczQCSmaWF78toLEmb0Zsw': 93, 'Prsk7SiPZNfgcPyygOdGHg': 41, 'HOleI3jz1MLNUJ6cc1x0Pw': 42, 'Cp-PV8rsypbO-xBrQ6KmQg': 37, 'BV8c4QZEzvPWA00ZqJp-jQ': 52, 'pv82zTlB5Txsu2Pusu__FA': 43, 'Rir-YRPPClKXDFQbc3BsVw': 31, 'bM2OTIopnFoaQGLxK2PxPg': 41, '0bNXP9quoJEgyVZu9ipGgQ': 65, '8J4IIYcqBlFch8T90N923A': 35, 'WWxCMDn8rVHIrIFoKRcRDg': 33, '4ozupHULqGyO42s3zNUzOQ': 81, 'v6rb-4YhADpuD99f3RKmgg': 35, 'k2u1F6spBGhgk2JtAe97QA': 36, 'DrKQzBFAvxhyjLgbPSW2Qw': 40, 'q9XgOylNsSbqZqF_SO3-OQ': 56, '4UUIpbOTPmu43wuC2aSGkg': 49, 'P2kVk4cIWyK4e4h14RhK-Q': 50, 'gBID8jIwsQIE5W_Zr0Vhjg': 31, '4_YfcfHkCem1onJFkItxjA': 34, 'BWo7K_QGZCO2PG1osiwRuQ': 34, 'tdNV2Wb0LrFpm1Yfov_Klw': 46, 'pW91HUnVz6ssLZ4dY-ztyQ': 38, 'qbfQRHLvZk5WSkKY0l_lMw': 38, 'NvDR3SPVPXrDB_dbKuGoWA': 41, 'xZvRLPJ1ixhFVomkXSfXAw': 62, 't-27_YZKsk9tMbAiwQKCwQ': 56, '0qIsBt4EzBDCKrIviV55Ew': 53, '8dbRf1UsWp2ktXHZ6Zv06w': 47, 'AZuSSh8xMwLtoapGa02WZQ': 41, 'J3rNWRLRuZJ_0xsJalIhlA': 34, 'SEDFpR4oMPKqXMjbJiMGog': 43, 'ARe8Nr_YehB2ubsGJhZ-hg': 53, 'JkMOQaMjlBHMqp6gj-hL3w': 51, 'pIm17SVRo8IdhGoBD4qbnA': 26, 'w6Vv-kldGpmvSGqXvTbAdQ': 43, 'X_kPh3nt0AJPNPHye2rTlA': 48, 'i63u3SdbrLsP4FxiSKP0Zw': 32, 'lxZSVeJz6KEBW1nlA3JKJg': 49, 'UCQNrwN4_hHHTWYa8cqe_Q': 34, 'lPaYMDmJbAnv_3pmZH_inw': 43, 'GJrGPKF2xxB06Es6aH1VWg': 38, 'F9T6m1YdRFreyKDufcyoOQ': 47, 'MWt24-6bfv_OHLKhwMQ0Tw': 52, '--65q1FpAL_UQtVZ2PTGew': 35, '0B72lj8x6TXrKuAYpaHL3w': 2, '6kmu0mYbdpMIOZ6Y0eVsxg': 55, 'y9IKf7VckFc-fesWuDwgxg': 47, 'pLAmvKJu0J3ng9d2fWa61g': 12, 'zZxr7X10CDThXZbnkLmNVA': 22, 'vsXP832M0kOxKpfduD7dWw': 55, 'C8ZTiwa7qWoPSMIivTeSfw': 74, 'IGkoathSlJmIOBDGo9vUZg': 53, 'snd45oedwXxF9tsHUX_6dg': 30, 'AgARllvBE2wIopbJSuSXPg': 26, '4A3dQlNtdL8uaMgXbHIEHg': 12, 'spJUPXI7QaIctU0FO5c42w': 37, 'kGgAARL2UmvCcTRfiscjug': 65, 'rpOyqD_893cqmDAtJLbdog': 49, '6IHcb7PC6qiYR9qEsBieVQ': 28, '78Ed1ndOak2kmzljulPfBg': 46, 'eBwBjylS66qPcHs2_ajLag': 45, 'Q96IRvil6RNgdLmGKuh81A': 44, 'fHv7k5vWd6ryt8jH4J3teg': 38, 'bmXuGmfu9LahwRMLjs5OXA': 38, 'mmJzZPMT06-4jRhf5L8laQ': 29, 'hjJPKQ1Ah91h3fVbc8GsOg': 36, '2rlBbFPHyZjXSFSE8r551w': 40, 'P-lfV8cdAgEOZJkw2dJpsw': 20, 'HW-cL93tvU7qng1sZueKWw': 32, 'saiZmxzBIowJbMgPBW1Now': 56, '8CNEh7fSbLwDuAKhLjDPKQ': 28}
# 93

# %%
fig = plt.figure(figsize=(15, 15))
plt.title('Yelp Connectivity Graph')
p = nx.degree_centrality(G)

min_value = max(p.itervalues())
#print min_value
def f(dict):
    for entry in dict.items():
        dict[entry[0]] = entry[1] / min_value
    return dict
p = f(p)
print p.values()

#nx.draw_networkx_nodes(G, pos=nx.spring_layout(G), nodelist=p.keys(),
#                      node_size=55, node_color=p.values(), cmap=plt.get_cmap('jet'))
#nx.draw_networkx_edges(G, pos=nx.spring_layout(G), alpha=.5)

values = [num_of_friends.get(node) for node in G.nodes()]
values = [0 if x is None else x for x in values]
#print values
nx.draw(G, node_size=60, node_color=values, cmap=plt.get_cmap('jet'),
        with_labels=False, alpha=0.5, pos=nx.spring_layout(G))
# Out:
# [0.34408602150537637, 0.46236559139784944, 0.6129032258064516, 0.3655913978494624, 0.23655913978494625, 0.3548387096774194, 0.7096774193548387, 0.4838709677419355, 0.45161290322580644, 0.41935483870967744, 0.40860215053763443, 0.4408602150537635, 0.37634408602150543, 0.4408602150537635, 0.4408602150537635, 0.6559139784946237, 0.4731182795698925, 0.4838709677419355, 0.6236559139784946, 0.6129032258064516, 0.4838709677419355, 0.40860215053763443, 0.37634408602150543, 0.5268817204301075, 0.41935483870967744, 0.43010752688172044, 0.6774193548387097, 0.5161290322580645, 1.0, 0.4408602150537635, 0.45161290322580644, 0.3978494623655914, 0.5591397849462366, 0.46236559139784944, 0.3333333333333333, 0.4408602150537635, 0.6989247311827956, 0.37634408602150543, 0.3548387096774194, 0.8709677419354839, 0.37634408602150543, 0.3870967741935484, 0.43010752688172044, 0.6021505376344086, 0.5268817204301075, 0.5376344086021505, 0.3333333333333333, 0.3655913978494624, 0.3655913978494624, 0.4946236559139785, 0.40860215053763443, 0.40860215053763443, 0.4408602150537635, 0.6666666666666666, 0.6021505376344086, 0.5698924731182795, 0.5053763440860215, 0.34408602150537637, 0.3655913978494624, 0.46236559139784944, 0.5698924731182795, 0.5483870967741936, 0.2795698924731183, 0.46236559139784944, 0.5161290322580645, 0.34408602150537637, 0.5268817204301075, 0.3655913978494624, 0.46236559139784944, 0.40860215053763443, 0.5053763440860215, 0.5591397849462366, 0.37634408602150543, 0.021505376344086023, 0.5913978494623656, 0.5053763440860215, 0.12903225806451613, 0.23655913978494625, 0.5913978494623656, 0.7956989247311828, 0.5698924731182795, 0.3225806451612903, 0.2795698924731183, 0.12903225806451613, 0.3978494623655914, 0.6989247311827956, 0.7634408602150538, 0.3010752688172043, 0.4946236559139785, 0.4838709677419355, 0.4731182795698925, 0.40860215053763443, 0.40860215053763443, 0.3118279569892473, 0.3870967741935484, 0.43010752688172044, 0.21505376344086022, 0.34408602150537637, 0.6021505376344086, 0.3010752688172043]

# %% [markdown]
# ##PROBLEMS 4 STANLEY TO THINK ABOUT
# 1. Runs really slowly - even with 100 points takes quite a while. This might be because it finds friends of the users so it actually plots roughly 8-10 x the # of points.  In the example above i subsample 10 pts but ended up with ~130 on the graph because each had roughly 13 friends.  When I ran it subsampling 1000 points I ended up with 11000 as my total node count.
#
# 2. We currently only display subsampled users and their friends. e.g. a graph with most vertices of degree 1, their only connection being to the original subsampled user.  Ideally we would like to have a graph that follows every edge until it hits a node/edge it previously created.  I am not sure whether this is possible to implement, seeing as how we would have to follow the edges we sample until we hit a "dead end" and if the graph is fully connected it would attempt to draw every edge.  Maybe subsample?
#
# 3.  Subsample approach:  From the initial 30,000 people with friends, subsample 1000 of them and remove the other 29,000 from the list of user_ids as well as any adjacency lists they may appear on.  Instead of just plotting the neighbors of a node now, we will attempt to plot every edge of every vertice, and since we removed 29,0000 points from our sample this may be more feasible and still give an accurate depiction of the original graph, but at 30,000 its infeasible to try to draw any conclusions from just graphing it both visually and computationally wise.
#
# 4. any other ideas?
