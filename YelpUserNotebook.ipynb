# %% [markdown]
# # Build a Social Network Graph

# %%
# %load_ext rmagic
import rpy2 as Rpy

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%R
# data_user <- read.csv("yelp_academic_dataset_user.csv", stringsAsFactors=FALSE)
# cat("Dimension of user dataset:\n"); print(dim(data_user))
# cat("Summary of user dataset:\n"); print(names(data_user))
# Out:
# Dimension of user dataset:
# [1] 70817    23
# Summary of user dataset:
#  [1] "average_stars"       "compliments_cool"    "compliments_cute"
#  [4] "compliments_funny"   "compliments_hot"     "compliments_list"
#  [7] "compliments_more"    "compliments_note"    "compliments_photos"
# [10] "compliments_plain"   "compliments_profile" "compliments_writer"
# [13] "elite"               "fans"                "friends"
# [16] "name"                "review_count"        "type"
# [19] "user_id"             "votes_cool"          "votes_funny"
# [22] "votes_useful"        "yelping_since"

# %%
# %%R
# indices <- data_user$friends!="[,]" # only sample users with friends
# data_user_f <- data_user[indices,]
# cat("Dimension of user dataset  w/ friends:\n"); print(dim(data_user_f))
# Out:
# Dimension of user dataset  w/ friends:
# [1] 30255    23

# %%
# %%R
# data_sample <- data_user_f[sample(nrow(data_user_f), 2000, replace = FALSE, prob = NULL),] #sampling a small # to run faster
#
# cat("Dimension of user dataset sample w/ friends:\n"); print(dim(data_sample))
# cat("Summary of user dataset sample w/ friends:\n"); print(names(data_sample))
# #print (data_sample$friends)
#
# ##PREPROCESSING
# keeps <- c("user_id","friends") # we are only interested in friends / connectivity
# friend_list <- data_sample[keeps]
# friend_list$friends<-gsub(',', '', friend_list$friends, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
# friend_list$friends<-gsub("u'", "", friend_list$friends, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
# friend_list$friends<-gsub("'", ",", friend_list$friends, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
# friend_list$friends<-gsub(",]", "", friend_list$friends, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
# friend_list$friends<-gsub("\\[", "", friend_list$friends, ignore.case = FALSE, perl = FALSE,
#      fixed = FALSE, useBytes = FALSE)
#
# #prints the first 5 elements of dataframe
# cat("Dimension of friend list:\n"); print(dim(friend_list))
# print(head(friend_list))
# Out:
# Dimension of user dataset sample w/ friends:
# [1] 2000   23
# Summary of user dataset sample w/ friends:
#  [1] "average_stars"       "compliments_cool"    "compliments_cute"
#  [4] "compliments_funny"   "compliments_hot"     "compliments_list"
#  [7] "compliments_more"    "compliments_note"    "compliments_photos"
# [10] "compliments_plain"   "compliments_profile" "compliments_writer"
# [13] "elite"               "fans"                "friends"
# [16] "name"                "review_count"        "type"
# [19] "user_id"             "votes_cool"          "votes_funny"
# [22] "votes_useful"        "yelping_since"
# Dimension of friend list:
# [1] 2000    2
#                      user_id
# 45585 f0lMTWhPFV1eWildG_UF2A
# 57746 _dIi1H1FQNTlqEVeLX9dpQ
# 28635 YgRRFj3UEv8RHpr8hGy-BA
# 67478 C0vujI9rPTA30iHyBYKlfg
# 52127 ev7kdleHADCh1G-ogdQGFw
# 31846 p-hrTR6nGHVNPgNZSXbMuQ
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                      friends
# 45585                                                                                                                                                                                                                                                                                                                                                                                                                         6J_V3M-6k7hziNfuWTGh2A, 5K4QOOlhDXMqEo6xOYlN2w
# 57746                                                                                                                                                                                                                                                                                                                                                 Tmdp9goVSoHXWSELkfQpFA, 0o0VMEJeQY0pAAZ9nxErBA, b8vpDCrjDwjXSr92JVp-PQ, siNULTrwgQWOGbvGSsjFmQ, iwUN95LIaEr75TZE_JC6bg
# 28635                                                                                                                                                                                                                                                                                                                                                                                                                                                 fHv7k5vWd6ryt8jH4J3teg
# 67478                                                                                                                                                                                                                                                                                                                                                                                                                                                 rIkxXjBKAeKKSYfLMgocLA
# 52127                                                                                                                                                                                                                                                                                                                                                                                                                         iMPo_LExRHHAh41kePLdNw, OnPinrgmj856qAN0haXvCw
# 31846 GjYhx_UBsndqJ5O0P7y3cw, zJlzNkIngaIV_crtUKdykQ, yAeo2D5NdtGuGG2o1M1aGQ, pYZQObhyQJqahGGgpdLNXg, fFfbppeVMh7mUbaMYvwS9g, vJZtiMtXJL0GHl8AzsKAFg, c7AyEUnJewJoV1Kdx5bm6g, 8d3AGso7vTLYxXrLrkO9aQ, wP4lQtQ_P3-0AkGplzZF2A, i8wqUZEi6jd3Stt3amIdzA, Rt-M0Vz3xolu7Me045AjvA, m8lOWAt-5_janwKiPte0-A, k8WnU0QmqrCLTPynzJhZmg, 4RuPTPxT12NoeYw69QJLUA, DWYH3H49-KhUoJX7TfidaQ, Nza2x1X87hk4AEYIwsG7Ww, NCNOWg4rVQ5tSOocNvWZxw, bwSdy7xVFhpZ-7yZD0AbAg, Tlrv1rxNnU1YY3PsLFvqZQ

# %%
import numpy
import networkx as nx

# %R -o friend_list

user_sample = friend_list[0] # original user subsample for constructing graph
friends_of_users = friend_list[1] #list of strings, where each string is list of adjacent nodes, we further parse below
all_nodes = [] #list of all nodes, including users and their friends
adj_list = [] #adjacency list per node, the results of the parsed friends_of_users list, a list of lists
num_of_friends = {}

for user in user_sample: # all initial sampled users to our nodes set
    all_nodes.append(user)
    

for friend_list in friends_of_users: # create adj_list out of string
    cur_list = []
    friends = friend_list.split(', ')
    for friend in friends:
        if friend in user_sample:
            cur_list.append(friend)
            #adj_list.append(friend.split(', ')) # originally friend is a long string so we have to split on ", " to parse
    adj_list.append(cur_list)

print "Our graph will have total " + str(len(all_nodes)) + " nodes."
print "Our adj list is  will have total " + str(len(adj_list)) + " long."
#print(adj_list)
# Out:
# Our graph will have total 2000 nodes.
# Our adj list is  will have total 2000 long.

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()

# adding just one node:
num_nodes = len(user_sample)
print "There are " + str(num_nodes) + " original subsampled nodes."

for node in all_nodes: # add all nodes to graph
    G.add_node(node)

for i in range(num_nodes): #iterate over every node we subsampled
    num_of_friends[user_sample[i]] = len(adj_list[i])
    for friend in adj_list[i]: #iterate over adjacency list in node
        if friend !="":
            G.add_edge(user_sample[i],friend) # add all edges to graph

print("Nodes of graph: "); print(G.nodes())
print("Edges of graph: "); print(G.edges())
print("Number of friends: "); print(num_of_friends)
print(max(num_of_friends.itervalues()))
# Out:
# There are 2000 original subsampled nodes.
# Nodes of graph:
# ['x_VNYP1vD8IekELWMp5IoA', 'ykHD2jjtQfVgxYS0dU_vwA', '9m7pitxpEEf6XPNKiiJirw', 'b23vORv1AGpKdj2OSxfdvw', 'Sjp6EYsqzdlTvymER6wBfg', 'J2JfCaiaZku8HgfNceU8Rg', 'F04SQWpesQ7Mb1_6yFHI7A', '1Q9pM0Hsls1rMuOvTuEGhw', '3sntAdhOgc2k-5w1g4urrQ', 'un9BdrRYhX94lI0R7uk6zg', '_h2h6TX5xhhWFIPMnpMd3g', 'jgYtI5zHyIiztN1K-qwWMg', 'AfeOBsRGWbaozKOgDF2pig', 'BBNiPq9HWuPAnylOfIo_qQ', '9Po7yCfKvRHEOkC92JrSIA', '7RBSJeEQRCnlzaIIo8FVXg', 'WbrKDU7seDYK05VMHBa8RA', 'zRfRRHZLyaIrK9pHNjbs0Q', 'NvqgVxpAM7wKjL9QeVWnnA', 'mXUGqzUsJcx___b0y72BZA', 'yOW_07olC5HaDlrzpEKECw', 'v3rJ6sNVlqrkbAlU0RIFCw', '6uq-vhHvXJwE6g2fYsNFmA', 'iOwgknqdvcxNz6FRtjPlMA', 'PcvV8zVgwpez9s6I-3Dykw', 'Br9mpMhkVunsp8Un5GpYWA', 'vbt_rKSSyoyNuud7Yjn6Qg', 'Gn3qmMaFoIf2Uom0muOm7A', 'X76Ja2Np2Dvy0cDTE03drw', 'cAJpG8briCwhX3KA7mly8g', 'Sv8p_q8YVOolDpjSedO52g', 'zRnoNCqk0DG3iOQxtpVXug', 'J2uKFrap275_b-UJLTnT-A', 'sDJ5yLATQFKBS2fr97svHQ', 'PQHAxYFxDngUbQLVyy23WQ', 'RbvcOMQagxqnhXl5vsvWNQ', '5WuKTuRZ7dt98hprNKiAgw', 'fXXfTxrYAipOtDHVedZN_Q', 'r6woroCw3-XTyvwY8mNu3Q', 'bXJ9U9e_zn8K1xKwqTArzw', 'oUupe5zP1CL4Zwqc8mVUIw', 'dBmOdTlEnEbGaPcnDfmZ_Q', 'CaWD1U962T7Vh8U3nuRsdA', 'RRgAVV9vsw6bL8FCrSMXPQ', 'pnUNmfEQ2ndtXozcQEkC8A', 'svhNfxHoXgiAE6HUiAeTyg', 'OXH3ASNaN-Ayz0BYtNlj8Q', 'bkpYoEkBlXyP55PofB_MnQ', 'Fm5S5V2QTNvxMNprbnq-Ew', 'F2bm-RcEaxqIqriybDgpXQ', '1NqzsgYtUwyngVyKzs_Lgg', 'QingGIjdfsPFHSuSgE1Ifg', 'p9H7tt-Cxi2cr4vne8QyhQ', 'X-6PjaHyBcGIo2_YnTvqIQ', 'YxRKHhhuWxX96_quP9Tgyg', 'WEdrmCByucoJD8Vsawkw8A', 'MA3O1Bemb-mJesDgzmF-2Q', 'ANTrWPSoOqbXkvLvxes-aA', 'nYJ07jJ45QxsxfvHObwj-g', 'EpC7vMp0hg1wGBQ6fzzoQg', '0NLlYgKL2dkORV0lBaTptA', '8-V8_9mX5oaOPRlHg-QQ9w', 'Z88vOiGEJGtkQnGKFfoUSg', 'iT1LJyp0FaCSRbz3UUFkMQ', 'NLIyErR75dlSv8ccNw62JA', 'TDbKPzfPclw3MxrpBISVcA', 'bJ1kVsEjJYUh17wg4H7o-g', '4wDBHlBv5gHZPNsmxPqYuA', 'ROoOHDHumh3Ea45dWm2I5g', '8DqIWXsKXOipfduYEfFpNw', 'lYIjuC5Wp34g0k99A07gOQ', '_GlP-J5IFotaIwuTJ0ezBQ', '26LAcjstVTKiN2YPJIkyvA', '7vduHeIL53L2ucINK3aj2Q', 'gTTWCAp2GjpKXk7bR-Tvuw', 'WCKZOvJ0rBRqI3NfCnh5Ig', 'VriJs4mjwAlPkNcP4gvjZA', 'qsRNxnsTbVL1ea83m-jY4Q', 'kbJNDcsBE-U_GiOY43hwwQ', 'ImmzK5sLsm5yBOZ8WKxyog', 'kgyv3ctYEZ0ACslpoakunw', 'Jq_apJB3Uf3Q_R9OeEuqBA', 'eg8DlR5X2294pHdkU5PFrA', 'GSVSgA4OqKGZXQC1Si5q6A', 'yHllpIen7qidlicr7-QUjA', 'OZjJGMHf5zYrEiGel7KywQ', 'LxgdyviWGbgvVp_L0DABpg', 'ENXoNHajFgba3q-6mM91rw', 'MRqz7PQi3KNmASuljLRg5A', 'VhckaXtC06O4YSBpVPXFgA', 'yJ22u_1l01H4NM3wCowIKw', 'dRrkgTRSoMHXFUZFUigZUg', 'maPSm8NAuFF_SbbUaORFXQ', '1H4Zkimy5c_iF6HX1GOrGQ', 'RRIJ3K04IS-qGHG16hNpVg', 'AqSvq29-1zPs60ueGNj41A', 'JgzKSNpR3_F50Ty-oIhJ1w', 'c04dZ5_tRAKy-eNsKVy_cQ', 'ASXkqzGDsKNEwHl3sWgd1g', 'l5pzI8wLr0UyvrCjDvGcRQ', 'sr-si3VuqdtMa5QUUA988Q', 'JWHMsbHBpN4FFk1f2YOVXA', '-VtylxgCHrVrsSCn55e9QA', 'VcAQSGLgTI0RBjrHlePWow', 'XR8f6AN3pt0GQDc-Vis0KA', '4aTxrWvo5GKwxmgmqeP6HA', 'mnqDRTE2SbyEYEzifWRCDQ', 'XlVWRYPMpocZr0T9SgLtIw', 'AWTv37Rg4YBfXN6wUbSHvA', 'MbJOllFenYqRpwOCoaWXtQ', 'sMZ-Rlmp_gHU5a3mN30Tog', 'skiZJN5OJTyyqP2oRVNhoQ', 'A8CLPJ_vdTDlFufTLwjrUw', 'MnDHJvePh4cWMrBgOp0_Ig', 'etS2EtsLGq_CuMcZ-bHO9A', '6YpVDYr21lcflt-sBbr9vw', 'saLlX6WK6rSy6eShPxnkzA', '3R5-Hz6taBBrLLPeZCLsSw', 'a_UGd-H5LZcbEgOLI_94GQ', 'q63UAjJlrZrvz50mcFG2Eg', 'ev7kdleHADCh1G-ogdQGFw', 'cfkOHnHp3zYOgbhcMuUA4Q', 'PJlnYMj_YGmQ3SuAXral4Q', 'iBQ4jpfp5_SgyQ-gO5fCOQ', '5UVxIS3gWIPtd9H8bMG0aQ', 'WWTo7dcxQiIuaQfX9Vlofw', '6BpnmEvPKiXg7bX6SfIiLA', 'aom-4my104ueMEqRBf3log', 'zKVrFcAqiR2faJXL0BOl2g', 'bvYk98zUE61KoWifshskpw', '92DKSLKGKTT-VuldiAQe4w', 'm68J0cmJIxkPj654p1eQBg', 'YKBoIgFeiOzqaRN6cR23Kg', '3y4hvopMEdMSVmZhoN1r9Q', '2W8kTEcYhkSL2yYSyHxOcw', 'IkOaRADjz1YxUXpe7BNf4A', 'zU0_Br_RMC4oYSISOXzWog', 'Wg5PCpaqUkqV5LJsYDkMTA', 'u1-8wpDNcXwF_dthanHoTA', '4BEP7fN-0q5V2ehJr4icKw', 'T_gR7-Ojp7k-J5PpUfd2wg', 'lnP7h3slD1eM84GWuPys6w', 'TxKPDkxuCtptw0WhUBWCRQ', 'iNaa5kTybBEmtVQKba5TAQ', 'o65vFDylFaUGiFzWNQ68hw', 'MU1zbIPSLYdwWadUUR4ctA', '3z425b5gFOKdcZxOo7acJQ', '2yuLXsg4wmaEaHroRqvtyw', '_IBuP5TOW6-83rDm5zSLhA', 'P-NHUAal77wTgPo7MK1HlA', 'fuyuv5OOxtrtl3oiR_xzwg', 'eBe8C0HPxxwig5SBsaTGrw', 'Uq6YoSvd6ly0uSjo2sjlRg', 'PsXHT33JxjnTeMRzvmF- ...
# Edges of graph:
# [('b23vORv1AGpKdj2OSxfdvw', 'cMmQsFyrYBv6hIE6NffqZQ'), ('J2JfCaiaZku8HgfNceU8Rg', 'PvhTAyo9IZA2qOpC0E2nLg'), ('J2JfCaiaZku8HgfNceU8Rg', 'VYVxxvbc1g8aH7kFCP16Bg'), ('J2JfCaiaZku8HgfNceU8Rg', 'BBNiPq9HWuPAnylOfIo_qQ'), ('J2JfCaiaZku8HgfNceU8Rg', 'at38auZMu6CkXohCnNlRvg'), ('J2JfCaiaZku8HgfNceU8Rg', 'walf6q48eUXet67ZcZq_lQ'), ('J2JfCaiaZku8HgfNceU8Rg', 'M1KscMT7L7HoJyhQ-Zv9Wg'), ('J2JfCaiaZku8HgfNceU8Rg', 'as8g3IMsTyaKh50_Il-oWg'), ('J2JfCaiaZku8HgfNceU8Rg', 'k60yW0XRImeFIGo2JApNsA'), ('BBNiPq9HWuPAnylOfIo_qQ', 'pjoghjb0ZcuDWHvz02dSVA'), ('BBNiPq9HWuPAnylOfIo_qQ', 'nZ9XFVETN4hxdK4qPb-T3Q'), ('WbrKDU7seDYK05VMHBa8RA', 'a_UGd-H5LZcbEgOLI_94GQ'), ('6uq-vhHvXJwE6g2fYsNFmA', 'oJsnqRror1DUmi3jWgbwaA'), ('iOwgknqdvcxNz6FRtjPlMA', '96Aka4GjUYuu_bwpQQslhw'), ('iOwgknqdvcxNz6FRtjPlMA', 'sp9H33n27MK0yMbSVJuiMw'), ('Br9mpMhkVunsp8Un5GpYWA', 'dpSNoo-OzlG0i8_shA99fg'), ('Br9mpMhkVunsp8Un5GpYWA', 'Sj8tXtdmAXt5SCkjzlGDsw'), ('Sv8p_q8YVOolDpjSedO52g', '2t9wSXQ3Luadi_eW7O6Tag'), ('bXJ9U9e_zn8K1xKwqTArzw', 'jYLWzzhZRwwyCZxMzSFGuw'), ('oUupe5zP1CL4Zwqc8mVUIw', 'rhVGtf8qXZDrp3O_r62NEw'), ('CaWD1U962T7Vh8U3nuRsdA', 'msVCaf1dBx3pDCuwGBx-aA'), ('CaWD1U962T7Vh8U3nuRsdA', '_ORm2zQNMgaEZHDgzV9lcQ'), ('RRgAVV9vsw6bL8FCrSMXPQ', 'ysBQMZiuZ7VSu_YAh-lE0Q'), ('F2bm-RcEaxqIqriybDgpXQ', 'pYsYs7eQ9SWqAaQS0xoRLA'), ('WEdrmCByucoJD8Vsawkw8A', '_wY1dHBXKN4NjB5IsIk4eQ'), ('Z88vOiGEJGtkQnGKFfoUSg', 'bX2M7ERjL7HUvHLSExyUmw'), ('Z88vOiGEJGtkQnGKFfoUSg', 'ysBQMZiuZ7VSu_YAh-lE0Q'), ('bJ1kVsEjJYUh17wg4H7o-g', '6WAgotdYcUZFF_U5HgIMPQ'), ('bJ1kVsEjJYUh17wg4H7o-g', 'CBRMrCvjyrwGpmvQsbod8Q'), ('4wDBHlBv5gHZPNsmxPqYuA', 'Ciaxl_ne1uv8ZYbobMX1TA'), ('4wDBHlBv5gHZPNsmxPqYuA', '6qTA7oelKwpevf1lL_bIVA'), ('4wDBHlBv5gHZPNsmxPqYuA', 'DfsrWRuuiET_-CEupb5NdA'), ('8DqIWXsKXOipfduYEfFpNw', '_wY1dHBXKN4NjB5IsIk4eQ'), ('8DqIWXsKXOipfduYEfFpNw', 'JRdTRHchEWH_qba8Y8P6cQ'), ('_GlP-J5IFotaIwuTJ0ezBQ', 'XJMSexMQLfy8oc4o7s05ZQ'), ('7vduHeIL53L2ucINK3aj2Q', 'txMhhj8rJOViJe-TlO4yJg'), ('WCKZOvJ0rBRqI3NfCnh5Ig', 'mZoajxG_bTa7StDSxCFp4A'), ('WCKZOvJ0rBRqI3NfCnh5Ig', 'gJrTS-8XuK11J2kdiKH5XA'), ('WCKZOvJ0rBRqI3NfCnh5Ig', 'Y_ZITL9cYCKgBgDCwUQrow'), ('kbJNDcsBE-U_GiOY43hwwQ', 'sjdQ7sAT6G3ibRRkFKrDlw'), ('ImmzK5sLsm5yBOZ8WKxyog', 'muVxoIDJqy5KMT_PjODrpA'), ('kgyv3ctYEZ0ACslpoakunw', 'jqVeTSin5GeRm0ceSg-PBA'), ('kgyv3ctYEZ0ACslpoakunw', 'iC-kXC7m0XKdbntAIBA46w'), ('kgyv3ctYEZ0ACslpoakunw', 'kDJ9PRlYugp5RIa9ontPZg'), ('Jq_apJB3Uf3Q_R9OeEuqBA', 'JxKHfSiUsCl0djbv1x7uWw'), ('yHllpIen7qidlicr7-QUjA', '4nJBEiUNzJdvf_9LNFKHjA'), ('LxgdyviWGbgvVp_L0DABpg', 'GpBKdOw0Dhm7ElOKXYv7_A'), ('yJ22u_1l01H4NM3wCowIKw', 'Iycf9KNRhxvR187Qu2zZHg'), ('dRrkgTRSoMHXFUZFUigZUg', 's64Go2bRaNObzorOHckwrg'), ('dRrkgTRSoMHXFUZFUigZUg', 'Eg_UL0XaV_g4Dr3AeGZHUw'), ('RRIJ3K04IS-qGHG16hNpVg', '63whBj13THZ2feOipOLD1Q'), ('AqSvq29-1zPs60ueGNj41A', '96Aka4GjUYuu_bwpQQslhw'), ('AqSvq29-1zPs60ueGNj41A', 'jXJ7ATyzVCoY2Kpz_dLIZg'), ('AqSvq29-1zPs60ueGNj41A', 'QqUbIACoSVHDaaswoFW3ng'), ('sr-si3VuqdtMa5QUUA988Q', 'sp9H33n27MK0yMbSVJuiMw'), ('sr-si3VuqdtMa5QUUA988Q', '4DXhDszXSHzhaUqOOc4RoQ'), ('-VtylxgCHrVrsSCn55e9QA', 'lczLjHO7zIhrmSlOXI3ohg'), ('AWTv37Rg4YBfXN6wUbSHvA', 'oJsnqRror1DUmi3jWgbwaA'), ('AWTv37Rg4YBfXN6wUbSHvA', 'mE2ll6yfwUvy-W7To3E0AQ'), ('skiZJN5OJTyyqP2oRVNhoQ', 'rPozktD5gxV6BIaHt5X5-g'), ('skiZJN5OJTyyqP2oRVNhoQ', 'W2hF5pw4oApWVP3061RQHw'), ('MnDHJvePh4cWMrBgOp0_Ig', '3gIfcQq5KxAegwCPXc83cQ'), ('MnDHJvePh4cWMrBgOp0_Ig', 'ysBQMZiuZ7VSu_YAh-lE0Q'), ('MnDHJvePh4cWMrBgOp0_Ig', 'W_7aQXf0uC4GKvte4tlewA'), ('saLlX6WK6rSy6eShPxnkzA', 'KcI2VGSvRhLAmw6vZrc8WQ'), ('a_UGd-H5LZcbEgOLI_94GQ', 'ovaovvsxV96TUKJhar3P0w'), ('cfkOHnHp3zYOgbhcMuUA4Q', 'RSBpPixPILehXxTyuGgEyg'), ('PJlnYMj_YGmQ3SuAXral4Q', '8KmHPVzyBW45_tXX8zU5mA'), ('iBQ4jpfp5_SgyQ-gO5fCOQ', 'K_nrZRDnIM1LH1HPVX1_6Q'), ('6BpnmEvPKiXg7bX6SfIiLA', '8SKTFGqqHSYGyg4De5rW5g'), ('2W8kTEcYhkSL2yYSyHxOcw', 'cvDcbVGYb7kHQ9c8CjE-3A'), ('4BEP7fN-0q5V2ehJr4icKw', 'WJkmgkrSPMHTfDTD3VgqqA'), ('4BEP7fN-0q5V2ehJr4icKw', 'E-4XVptsZFhPQhXjEHoxUw'), ('4BEP7fN-0q5V2ehJr4icKw', 'ZWOj6LmzwGvMDh-A85EOtA'), ('4 ...
# Number of friends:
# {'x_VNYP1vD8IekELWMp5IoA': 0, 'ykHD2jjtQfVgxYS0dU_vwA': 0, '9m7pitxpEEf6XPNKiiJirw': 0, 'b23vORv1AGpKdj2OSxfdvw': 1, 'Sjp6EYsqzdlTvymER6wBfg': 0, 'J2JfCaiaZku8HgfNceU8Rg': 8, 'F04SQWpesQ7Mb1_6yFHI7A': 0, '1Q9pM0Hsls1rMuOvTuEGhw': 0, '3sntAdhOgc2k-5w1g4urrQ': 0, 'un9BdrRYhX94lI0R7uk6zg': 0, '_h2h6TX5xhhWFIPMnpMd3g': 0, 'jgYtI5zHyIiztN1K-qwWMg': 0, 'AfeOBsRGWbaozKOgDF2pig': 0, 'BBNiPq9HWuPAnylOfIo_qQ': 3, '9Po7yCfKvRHEOkC92JrSIA': 0, '7RBSJeEQRCnlzaIIo8FVXg': 0, 'WbrKDU7seDYK05VMHBa8RA': 1, 'zRfRRHZLyaIrK9pHNjbs0Q': 0, 'NvqgVxpAM7wKjL9QeVWnnA': 0, 'mXUGqzUsJcx___b0y72BZA': 0, 'yOW_07olC5HaDlrzpEKECw': 0, 'v3rJ6sNVlqrkbAlU0RIFCw': 0, '6uq-vhHvXJwE6g2fYsNFmA': 1, 'iOwgknqdvcxNz6FRtjPlMA': 2, 'PcvV8zVgwpez9s6I-3Dykw': 0, 'Br9mpMhkVunsp8Un5GpYWA': 2, 'vbt_rKSSyoyNuud7Yjn6Qg': 0, 'Gn3qmMaFoIf2Uom0muOm7A': 0, 'X76Ja2Np2Dvy0cDTE03drw': 0, 'cAJpG8briCwhX3KA7mly8g': 0, 'Sv8p_q8YVOolDpjSedO52g': 1, 'zRnoNCqk0DG3iOQxtpVXug': 0, 'J2uKFrap275_b-UJLTnT-A': 0, 'sDJ5yLATQFKBS2fr97svHQ': 0, 'PQHAxYFxDngUbQLVyy23WQ': 0, 'RbvcOMQagxqnhXl5vsvWNQ': 0, '5WuKTuRZ7dt98hprNKiAgw': 0, 'fXXfTxrYAipOtDHVedZN_Q': 0, 'r6woroCw3-XTyvwY8mNu3Q': 0, 'bXJ9U9e_zn8K1xKwqTArzw': 1, 'oUupe5zP1CL4Zwqc8mVUIw': 1, 'dBmOdTlEnEbGaPcnDfmZ_Q': 0, 'CaWD1U962T7Vh8U3nuRsdA': 2, 'RRgAVV9vsw6bL8FCrSMXPQ': 1, 'pnUNmfEQ2ndtXozcQEkC8A': 0, 'svhNfxHoXgiAE6HUiAeTyg': 0, 'OXH3ASNaN-Ayz0BYtNlj8Q': 0, 'bkpYoEkBlXyP55PofB_MnQ': 0, 'Fm5S5V2QTNvxMNprbnq-Ew': 0, 'F2bm-RcEaxqIqriybDgpXQ': 1, '1NqzsgYtUwyngVyKzs_Lgg': 0, 'QingGIjdfsPFHSuSgE1Ifg': 0, 'p9H7tt-Cxi2cr4vne8QyhQ': 0, 'X-6PjaHyBcGIo2_YnTvqIQ': 0, 'YxRKHhhuWxX96_quP9Tgyg': 0, 'WEdrmCByucoJD8Vsawkw8A': 1, 'MA3O1Bemb-mJesDgzmF-2Q': 0, 'ANTrWPSoOqbXkvLvxes-aA': 0, 'nYJ07jJ45QxsxfvHObwj-g': 0, 'EpC7vMp0hg1wGBQ6fzzoQg': 0, '0NLlYgKL2dkORV0lBaTptA': 0, '8-V8_9mX5oaOPRlHg-QQ9w': 0, 'Z88vOiGEJGtkQnGKFfoUSg': 2, 'iT1LJyp0FaCSRbz3UUFkMQ': 0, 'NLIyErR75dlSv8ccNw62JA': 0, 'TDbKPzfPclw3MxrpBISVcA': 0, 'bJ1kVsEjJYUh17wg4H7o-g': 2, '4wDBHlBv5gHZPNsmxPqYuA': 3, 'ROoOHDHumh3Ea45dWm2I5g': 0, '8DqIWXsKXOipfduYEfFpNw': 2, 'lYIjuC5Wp34g0k99A07gOQ': 0, '_GlP-J5IFotaIwuTJ0ezBQ': 1, '26LAcjstVTKiN2YPJIkyvA': 0, '7vduHeIL53L2ucINK3aj2Q': 1, 'gTTWCAp2GjpKXk7bR-Tvuw': 0, 'WCKZOvJ0rBRqI3NfCnh5Ig': 3, 'VriJs4mjwAlPkNcP4gvjZA': 0, 'qsRNxnsTbVL1ea83m-jY4Q': 0, 'kbJNDcsBE-U_GiOY43hwwQ': 1, 'ImmzK5sLsm5yBOZ8WKxyog': 1, 'kgyv3ctYEZ0ACslpoakunw': 3, 'Jq_apJB3Uf3Q_R9OeEuqBA': 1, 'eg8DlR5X2294pHdkU5PFrA': 0, 'GSVSgA4OqKGZXQC1Si5q6A': 0, 'yHllpIen7qidlicr7-QUjA': 1, 'OZjJGMHf5zYrEiGel7KywQ': 0, 'LxgdyviWGbgvVp_L0DABpg': 1, 'ENXoNHajFgba3q-6mM91rw': 0, 'MRqz7PQi3KNmASuljLRg5A': 0, 'VhckaXtC06O4YSBpVPXFgA': 0, 'yJ22u_1l01H4NM3wCowIKw': 1, 'dRrkgTRSoMHXFUZFUigZUg': 2, 'maPSm8NAuFF_SbbUaORFXQ': 0, '1H4Zkimy5c_iF6HX1GOrGQ': 0, 'RRIJ3K04IS-qGHG16hNpVg': 1, 'AqSvq29-1zPs60ueGNj41A': 3, 'JgzKSNpR3_F50Ty-oIhJ1w': 0, 'c04dZ5_tRAKy-eNsKVy_cQ': 0, 'ASXkqzGDsKNEwHl3sWgd1g': 0, 'l5pzI8wLr0UyvrCjDvGcRQ': 0, 'sr-si3VuqdtMa5QUUA988Q': 2, 'JWHMsbHBpN4FFk1f2YOVXA': 0, '-VtylxgCHrVrsSCn55e9QA': 1, 'VcAQSGLgTI0RBjrHlePWow': 0, 'XR8f6AN3pt0GQDc-Vis0KA': 0, '4aTxrWvo5GKwxmgmqeP6HA': 0, 'mnqDRTE2SbyEYEzifWRCDQ': 0, 'XlVWRYPMpocZr0T9SgLtIw': 0, 'AWTv37Rg4YBfXN6wUbSHvA': 2, 'MbJOllFenYqRpwOCoaWXtQ': 0, 'sMZ-Rlmp_gHU5a3mN30Tog': 0, 'skiZJN5OJTyyqP2oRVNhoQ': 2, 'A8CLPJ_vdTDlFufTLwjrUw': 0, 'MnDHJvePh4cWMrBgOp0_Ig': 3, 'etS2EtsLGq_CuMcZ-bHO9A': 0, '6YpVDYr21lcflt-sBbr9vw': 0, 'saLlX6WK6rSy6eShPxnkzA': 1, '3R5-Hz6taBBrLLPeZCLsSw': 0, 'a_UGd-H5LZcbEgOLI_94GQ': 2, 'q63UAjJlrZrvz50mcFG2Eg': 0, 'ev7kdleHADCh1G-ogdQGFw': 0, 'cfkOHnHp3zYOgbhcMuUA4Q': 1, 'PJlnYMj_YGmQ3SuAXral4Q': 1, 'iBQ4jpfp5_SgyQ-gO5fCOQ': 1, '5UVxIS3gWIPtd9H8bMG0aQ': 0, 'WWTo7dcxQiIuaQfX9Vlofw': 0, '6BpnmEvPKiXg7bX6SfIiLA': 1, 'aom-4my104ueMEqRBf3log': 0, 'zKVrFcAqiR2faJXL0BOl2g': 0, 'bvYk98zUE61KoWifshskpw': 0, '92DKSLKGKTT-VuldiAQe4w': 0, 'm68J0cmJIxkPj654p1eQBg': 0, 'YKBoIgFeiOzqaRN6cR23Kg': 0, '3y4hvopMEdMSVmZhoN1r9Q': 0, '2W8kTEcYhkSL2yYSyHxOcw': 1, 'IkOaRADjz1YxUXpe7BNf4A': 0, 'zU0_Br_RMC4oYSISOXzWog': 0, 'Wg5PCpaqUkqV5LJsYDkMTA':  ...
# 24

# %%
fig = plt.figure(figsize=(15, 15))
plt.title('Yelp Connectivity Graph')
p = nx.degree_centrality(G)

min_value = max(p.itervalues())
#print min_value
def f(dict):
    for entry in dict.items():
        dict[entry[0]] = entry[1] / min_value
    return dict
p = f(p)
#print p.values()

#nx.draw_networkx_nodes(G, pos=nx.spring_layout(G), nodelist=p.keys(),
#                      node_size=55, node_color=p.values(), cmap=plt.get_cmap('jet'))
#nx.draw_networkx_edges(G, pos=nx.spring_layout(G), alpha=.5)

values = [num_of_friends.get(node) for node in G.nodes()]
values = [0 if x is None else x for x in values]
#print values
nx.draw(G, node_size=60, node_color=values, cmap=plt.get_cmap('jet'),
        with_labels=False, alpha=0.5, pos=nx.spring_layout(G))

# %% [markdown]
# ##PROBLEMS 4 STANLEY TO THINK ABOUT
# 1. Runs really slowly - even with 100 points takes quite a while. This might be because it finds friends of the users so it actually plots roughly 8-10 x the # of points.  In the example above i subsample 10 pts but ended up with ~130 on the graph because each had roughly 13 friends.  When I ran it subsampling 1000 points I ended up with 11000 as my total node count.
#
# 2. We currently only display subsampled users and their friends. e.g. a graph with most vertices of degree 1, their only connection being to the original subsampled user.  Ideally we would like to have a graph that follows every edge until it hits a node/edge it previously created.  I am not sure whether this is possible to implement, seeing as how we would have to follow the edges we sample until we hit a "dead end" and if the graph is fully connected it would attempt to draw every edge.  Maybe subsample?
#
# 3.  Subsample approach:  From the initial 30,000 people with friends, subsample 1000 of them and remove the other 29,000 from the list of user_ids as well as any adjacency lists they may appear on.  Instead of just plotting the neighbors of a node now, we will attempt to plot every edge of every vertice, and since we removed 29,0000 points from our sample this may be more feasible and still give an accurate depiction of the original graph, but at 30,000 its infeasible to try to draw any conclusions from just graphing it both visually and computationally wise.
#
# 4. any other ideas?
